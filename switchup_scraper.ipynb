# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5-6 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from pandas import json_normalize
import re
import numpy as np
import time
import multiprocessing
import concurrent

# %%
school_list = ['Springboard', 
             'Dataquest',
             'Syntax Technologies',
             'ironhack',
             'tripleten',
             'Colaberry',
             'Maven Analytics',
             'Udacity',
             'BrainStation',
             'CCS Learning Academy',
             'Thinkful',
             'General Assembly']

# %%
school_id_dict = {}

# %%
for school_name in school_list:
    url = f"https://www.switchup.org/bootcamps/{school_name.lower().replace(' ', '-')}"
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        page_data_tag = soup.find('page-data')

        if page_data_tag:
            school_id = page_data_tag.get('school-id')
            if school_id:
                school_id_dict[school_name.lower().replace(' ','-')] = int(school_id)
                print(f"school ID for : {school_name}/{school_id}")
            else:
                print(f"School ID not found: {school_name}")
        else:
            print(f"Page data not found: {school_name}")

    else:
        print(f"Error: {response.status_code}")

print("School ID dictionary:", school_id_dict)
# Out:
# school ID for : Springboard/11035
# school ID for : Dataquest/10683
# school ID for : Syntax Technologies/11797
# school ID for : ironhack/10828
# school ID for : tripleten/11225
# school ID for : Colaberry/11718
# school ID for : Maven Analytics/11740
# school ID for : Udacity/11118
# school ID for : BrainStation/10571
# school ID for : CCS Learning Academy/11736
# school ID for : Thinkful/11098
# school ID for : General Assembly/10761
# School ID dictionary: {'springboard': 11035, 'dataquest': 10683, 'syntax-technologies': 11797, 'ironhack': 10828, 'tripleten': 11225, 'colaberry': 11718, 'maven-analytics': 11740, 'udacity': 11118, 'brainstation': 10571, 'ccs-learning-academy': 11736, 'thinkful': 11098, 'general-assembly': 10761}

# %%
school_id_dict
# Out:
# {'springboard': 11035,
#  'dataquest': 10683,
#  'syntax-technologies': 11797,
#  'ironhack': 10828,
#  'tripleten': 11225,
#  'colaberry': 11718,
#  'maven-analytics': 11740,
#  'udacity': 11118,
#  'brainstation': 10571,
#  'ccs-learning-academy': 11736,
#  'thinkful': 11098,
#  'general-assembly': 10761}

# %%
schools = school_id_dict

# %%
def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
schools
# Out:
# {'springboard': 11035,
#  'dataquest': 10683,
#  'syntax-technologies': 11797,
#  'ironhack': 10828,
#  'tripleten': 11225,
#  'colaberry': 11718,
#  'maven-analytics': 11740,
#  'udacity': 11118,
#  'brainstation': 10571,
#  'ccs-learning-academy': 11736,
#  'thinkful': 11098,
#  'general-assembly': 10761}

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))
comments = pd.concat(comments)
# Out:
# springboard
# dataquest
# syntax-technologies
# ironhack
# tripleten
# colaberry
# maven-analytics
# udacity
# brainstation
# ccs-learning-academy
# thinkful
# general-assembly

# %%
comments
# Out:
#          id              name  anonymous  hostProgramName  graduatingYear  \
# 0    306549  Daniel Dluzynski      False             None          2023.0
# 1    306505     Jonathan Chiu      False             None          2023.0
# 2    306504         Anonymous       True             None          2023.0
# 3    306451         Anonymous       True             None          2023.0
# 4    306317         Anonymous       True             None          2023.0
# ..      ...               ...        ...              ...             ...
# 994  231691       Abby Howell      False             None          2013.0
# 995  231827         Anonymous      False             None             NaN
# 996  231816      Thomas Berry      False             None             NaN
# 997  231836     Ryan Racioppo      False             None             NaN
# 998  231574         Vivien S.      False  Web Development             NaN
#
#     isAlumni                                jobTitle  \
# 0      False
# 1      False
# 2      False
# 3       True                            UX/UI Design
# 4      False                              Tech Sales
# ..       ...                                     ...
# 994     True  Software Developer at Cengage Learning
# 995    False
# 996    False
# 997    False
# 998     None                                    None
#
#                                                tagline  \
# 0                  Extensive and well built curriculum
# 1    Join if you're looking to structure &amp; Netw...
# 2    Join if you're looking to structure &amp; Netw...
# 3                                            Wonderful
# 4                         My experience at Springboard
# ..                                                 ...
# 994  From 2nd grade teacher to full-stack web devel...
# 995  What you get out of the program really depends...
# 996  The bitmaker program provides opportunities an...
# 997  Bitmaker is the best way to motivate and accel...
# 998                                               NULL
#
#                                                   body  \
# 0    <span class="truncatable"><p></p><p>This cours...
# 1    <span class="truncatable"><p></p><p>If you fin...
# 2    <span class="truncatable"><p></p><p>If you fin...
# 3    <span class="truncatable"><p></p><p>Pros: I fo...
# 4    <span class="truncatable"><p></p><p>My experie...
# ..                                                 ...
# 994  <span class="truncatable"><p>My experience at ...
# 995  <span class="truncatable"><p></p><p>What you g...
# 996  <span class="truncatable"><p></p><p>Personally...
# 997  <span class="truncatable"><p></p><p>I was in t...
# 998  <span class="truncatable"><p></p><p>I'm surpri...
#
#                                                rawBody  ...   queryDate  \
# 0    <p>This course is great for beginners. The cur...  ...  2023-11-17
# 1    <p>If you find yourself unsure of where to beg...  ...  2023-11-15
# 2    <p>If you find yourself unsure of where to beg...  ...  2023-11-15
# 3    <p>Pros: I found the Springboard bootcamp to b...  ...  2023-11-14
# 4    <p>My experience at Springboard was great. Won...  ...  2023-11-08
# ..                                                 ...  ...         ...
# 994  My experience at General Assembly's Web Develo...  ...  2014-06-29
# 995  <p>What you get out of the program really depe...  ...  2014-06-15
# 996  <p>Personally I had a great experience at Bitm...  ...  2014-06-15
# 997  <p>I was in the 3rd cohort and have had a succ...  ...  2014-06-15
# 998  <p>I&#39;m surprised by the reviews below. My ...  ...  2013-12-19
#
#                             program             user overallScore comments  \
# 0       Cyber Security Career Track  {'image': None}          4.3       []
# 1         UI/UX Design Career Track  {'image': None}          4.0       []
# 2         UI/UX Design Career Track  {'image': None}          4.0       []
# 3         UI/UX Design Career Track  {'image': None}          4.3       []
# 4           Tech Sales Career Track  {'image': None}          5.0       []
# ..                              ...              ...          ...      ...
# 994  Software Engineering Immersive  {'image': None}          5.0       []
# 995                                  {'image': None}          3.0       []
# 996                                  {'image': None}          5.0       []
# 997                                  {'image': None}          5.0       []
# 998                            None  {'image': None}          4.0       []
#
#     overall curriculum jobSupport  \
# 0       4.0        5.0        4.0
# 1       4.0        4.0        4.0
# 2       4.0        4.0        4.0
# 3       4.0        5.0        4.0
# 4       5.0        5.0        5.0
# ..      ...        ...        ...
# 994     5.0        5.0        5.0
# 995     3.0        NaN        NaN
# 996     5.0        NaN        NaN
# 997     5.0        NaN        NaN
# 998     4.0        NaN        NaN
#
#                                            review_body            school
# 0    This course is great for beginners. The curric...       springboard
# 1    If you find yourself unsure of where to begin,...       springboard
# 2    If you find yourself unsure of where to begin,...       springboard
# 3    Pros: I found the Springboard bootcamp to be i...       springboard
# 4    My experience at Springboard was great. Wonder...       springboard
# ..                                                 ...               ...
# 994  My experience at General Assembly's Web Develo...  general-assembly
# 995  What you get out of the program really depends...  general-assembly
# 996  Personally I had a great experience at Bitmake...  general-assembly
# 997  I was in the 3rd cohort and have had a success...  general-assembly
# 998  I'm surprised by the reviews below. My experie...  general-assembly
#
# [6988 rows x 21 columns]

# %%
from pandas import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# springboard
# dataquest
# syntax-technologies
# ironhack
# tripleten
# colaberry
# maven-analytics
# udacity
# brainstation
# ccs-learning-academy
# thinkful
# general-assembly

# %%
locations_list
# Out:
#       id description  state.id state.name state.abbrev state.keyword  \
# 0  17154      Online         1     Online       Online        online
#
#       school  school_id
# 0  tripleten      11225

# %%
locations = pd.concat(locations_list)
locations
# Out:
#       id               description  state.id        state.name state.abbrev  \
# 0  16013                    Online       1.0            Online       Online
# 0  16378                    Online       1.0            Online       Online
# 0  18261                    Online       1.0            Online       Online
# 0  15901           Berlin, Germany       NaN               NaN          NaN
# 1  16022       Mexico City, Mexico       NaN               NaN          NaN
# 2  16086    Amsterdam, Netherlands       NaN               NaN          NaN
# 3  16088         Sao Paulo, Brazil       NaN               NaN          NaN
# 4  16109             Paris, France       NaN               NaN          NaN
# 5  16375  Miami, FL, United States      11.0           Florida           FL
# 6  16376             Madrid, Spain       NaN               NaN          NaN
# 7  16377          Barcelona, Spain       NaN               NaN          NaN
# 8  16709          Lisbon, Portugal       NaN               NaN          NaN
# 9  17233                    Online       1.0            Online       Online
# 0  17154                    Online       1.0            Online       Online
# 0  18073                    Online       1.0            Online       Online
# 0  18116                    Online       1.0            Online       Online
# 0  15807                    Online       1.0            Online       Online
# 0  15935         New York City, NY      34.0          New York           NY
# 1  15985           Toronto, Canada      66.0           Ontario           ON
# 2  16010         Vancouver, Canada      71.0  British Columbia           BC
# 3  16909                Boston, MA      23.0     Massachusetts           MA
# 4  16910               Chicago, IL      15.0          Illinois           IL
# 5  16940                    Online       1.0            Online       Online
# 6  17706                 Miami, FL      11.0           Florida           FL
# 7  17731                London, UK       NaN               NaN          NaN
# 0  18109                    Online       1.0            Online       Online
# 0  16383                    Online       1.0            Online       Online
# 0  16360         New York City, NY      34.0          New York           NY
# 1  16372                    Online       1.0            Online       Online
# 2  16961                London, UK       NaN               NaN          NaN
# 3  17033           Toronto, Canada      66.0           Ontario           ON
#
#    state.keyword                school  school_id  country.id    country.name  \
# 0         online           springboard      11035         NaN             NaN
# 0         online             dataquest      10683         NaN             NaN
# 0         online   syntax-technologies      11797         NaN             NaN
# 0            NaN              ironhack      10828        57.0         Germany
# 1            NaN              ironhack      10828        29.0          Mexico
# 2            NaN              ironhack      10828        59.0     Netherlands
# 3            NaN              ironhack      10828        42.0          Brazil
# 4            NaN              ironhack      10828        38.0          France
# 5        florida              ironhack      10828         1.0   United States
# 6            NaN              ironhack      10828        12.0           Spain
# 7            NaN              ironhack      10828        12.0           Spain
# 8            NaN              ironhack      10828        28.0        Portugal
# 9         online              ironhack      10828         NaN             NaN
# 0         online             tripleten      11225         NaN             NaN
# 0         online             colaberry      11718         NaN             NaN
# 0         online       maven-analytics      11740         NaN             NaN
# 0         online               udacity      11118         NaN             NaN
# 0       new-york          brainstation      10571         1.0   United States
# 1                         brainstation      10571         2.0          Canada
# 2                         brainstation      10571         2.0          Canada
# 3  massachusetts          brainstation      10571         1.0   United States
# 4       illinois          brainstation      10571         1.0   United States
# 5         online          brainstation      10571         NaN             NaN
# 6        florida          brainstation      10571         1.0   United States
# 7            NaN          brainstation      10571        11.0  United Kingdom
# 0         online  ccs-learning-academy      11736         NaN             NaN
# 0         online              thinkful      11098         NaN             NaN
# 0       new-york      general-assembly      10761         1.0   United States
# 1         online      general-assembly      10761         NaN             NaN
# 2            NaN      general-assembly      10761        11.0  United Kingdom
# 3                     general-assembly      10761         2.0          Canada
#
#   country.abbrev  city.id    city.name   city.keyword
# 0            NaN      NaN          NaN            NaN
# 0            NaN      NaN          NaN            NaN
# 0            NaN      NaN          NaN            NaN
# 0             DE  31156.0       Berlin         berlin
# 1             MX  31175.0  Mexico City    mexico-city
# 2             NL  31168.0    Amsterdam      amsterdam
# 3             BR  31121.0    Sao Paulo      sao-paulo
# 4             FR  31136.0        Paris          paris
# 5             US     31.0        Miami          miami
# 6             ES  31052.0       Madrid         madrid
# 7             ES  31170.0    Barcelona      barcelona
# 8             PT  31075.0       Lisbon         lisbon
# 9            NaN      NaN          NaN            NaN
# 0            NaN      NaN          NaN            NaN
# 0            NaN      NaN          NaN            NaN
# 0            NaN      NaN          NaN            NaN
# 0            NaN      NaN          NaN            NaN
# 0             US   1507.0          NYC  new-york-city
# 1             CA  31152.0      Toronto        toronto
# 2             CA  31138.0    Vancouver      vancouver
# 3             US     47.0       Boston         boston
# 4             US     39.0      Chicago        chicago
# 5            NaN      NaN          NaN            NaN
# 6             US     31.0        Miami          miami
# 7             GB  31176.0       London         london
# 0            NaN      NaN          NaN            NaN
# 0            NaN      NaN          NaN            NaN
# 0             US   1507.0          NYC  new-york-city
# 1            NaN      NaN          NaN            NaN
# 2             GB  31176.0       London         london
# 3             CA  31152.0      Toronto        toronto

# %%
courses = pd.concat(courses_list)
courses.head(10)
# Out:
#                                          courses       school  school_id
# 0                    Cyber Security Career Track  springboard      11035
# 1                    Data Analytics Career Track  springboard      11035
# 2                      Data Science Career Track  springboard      11035
# 3                 Data Science Career Track Prep  springboard      11035
# 4                      Front-End Web Development  springboard      11035
# 5                 Introduction to Data Analytics  springboard      11035
# 6                         Introduction to Design  springboard      11035
# 7              Software Engineering Career Track  springboard      11035
# 8  Software Engineering Career Track Prep Course  springboard      11035
# 9       Software Engineering Foundations to Core  springboard      11035

# %%
badges = pd.concat(badges_list)
badges.head()
# Out:
#                name           keyword  \
# 0  Available Online  available_online
# 1  Flexible Classes  flexible_classes
# 2     Job Guarantee     job_guarantee
# 0  Available Online  available_online
# 1  Flexible Classes  flexible_classes
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>  springboard      11035
# 1  <p>School offers part-time and evening classes...  springboard      11035
# 2             <p>School guarantees job placement</p>  springboard      11035
# 0          <p>School offers fully online courses</p>    dataquest      10683
# 1  <p>School offers part-time and evening classes...    dataquest      10683

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools
# Out:
#                                              website  \
# 0  www.springboard.com/?utm_source=switchup&utm_m...
# 0                                   www.dataquest.io
# 0                               www.syntaxtechs.com/
# 0                                www.ironhack.com/en
# 0  tripleten.com/?utm_source=referral&utm_medium=...
# 0                                 www.colaberry.com/
# 0                             www.mavenanalytics.io/
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
# 0                                    brainstation.io
# 0                            ccslearningacademy.com/
# 0                                      thinkful.com/
# 0  generalassemb.ly?utm_source=switchup&utm_mediu...
#
#                                          description  \
# 0  <span class="truncatable"><p>Springboard is an...
# 0  <span class="truncatable"><p>Master data skill...
# 0  <span class="truncatable"><p>Syntax Technologi...
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>Tripleten changed...
# 0  <span class="truncatable"><p>Colaberry offers ...
# 0  <span class="truncatable"><p>Maven Analytics i...
# 0  <span class="truncatable"><p>Udacity is the tr...
# 0  <span class="truncatable"><p>BrainStation is t...
# 0  <span class="truncatable"><p>TECH TRAINING BY ...
# 0  <span class="truncatable"><p>Thinkful teaches ...
# 0  <span class="truncatable"><p>General Assembly ...
#
#                                              LogoUrl                school  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...           springboard
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             dataquest
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...   syntax-technologies
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...              ironhack
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             tripleten
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             colaberry
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...       maven-analytics
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...               udacity
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          brainstation
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  ccs-learning-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...              thinkful
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...      general-assembly
#
#    school_id
# 0      11035
# 0      10683
# 0      11797
# 0      10828
# 0      11225
# 0      11718
# 0      11740
# 0      11118
# 0      10571
# 0      11736
# 0      11098
# 0      10761
